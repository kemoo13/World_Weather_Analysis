# %%
# Import the dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
import requests
from config import weather_api_key
from citipy import citipy
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations and save them to access later - note 6.1.4 for more info
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities=[]

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %%
# Get the base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list (we will use enurmerate to get the index of the city for logging purposes, otherwise we
# will get a programming error when building the city_url b/c it adds the index not the city name to the city_url) 6.2.6
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | verkhniy baskunchak
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | westport
# Processing Record 5 of Set 1 | kem
# Processing Record 6 of Set 1 | namibe
# Processing Record 7 of Set 1 | kargasok
# Processing Record 8 of Set 1 | manaus
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | jacareacanga
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | surt
# Processing Record 15 of Set 1 | laguna
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | bereda
# Processing Record 20 of Set 1 | wisconsin rapids
# Processing Record 21 of Set 1 | sao felix do xingu
# Processing Record 22 of Set 1 | aswan
# Processing Record 23 of Set 1 | la vega
# Processing Record 24 of Set 1 | sao miguel do iguacu
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | floro
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | aripuana
# Processing Record 30 of Set 1 | damaturu
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | axim
# Processing Record 33 of Set 1 | beberibe
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | clarence town
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | orthez
# Processing Record 39 of Set 1 | bageshwar
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | hualmay
# Processing Record 42 of Set 1 | puno
# Processing Record 43 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | semnan
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | huambo
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | rumonge
# Processing Record 3 of Set 2 | oslo
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | grand gaube
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | mariental
# Processing Record 9 of Set 2 | adeje
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | barra do garcas
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | somerset
# Processing Record 15 of Set 2 | tillabery
# City not found. Skipping...
# Processing Record 16 of Set 2 | karpogory
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | maxixe
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | buchanan
# Processing Record 21 of Set 2 | thurso
# Processing Record 22 of Set 2 | chipiona
# Processing Record 23 of Set 2 | alice town
# Processing Record 24 of Set 2 | uthal
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | paamiut
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | ornes
# Processing Record 29 of Set 2 | fort-shevchenko
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | estepa
# Processing Record 32 of Set 2 | olinda
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | tazovskiy
# Processing Record 35 of Set 2 | camacha
# Processing Record 36 of Set 2 | ugoofaaru
# Processing Record 37 of Set 2 | santa rosa
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | sistranda
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | nueva italia
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | viedma
# Processing Record 45 of Set 2 | araouane
# Processing Record 46 of Set 2 | tessalit
# Processing Record 47 of Set 2 | port hawkesbury
# Processing Record 48 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 49 of Set 2 | turayf
# Processing Record 50 of Set 2 | istria
# Processing Record 1 of Set 3 | road town
# Processing Record 2 of Set 3 | maniitsoq
# Processing Record 3 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 3 | lagoa
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | kasongo-lunda
# Processing Record 7 of Set 3 | kudymkar
# Processing Record 8 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 3 | san cristobal
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | korla
# Processing Record 12 of Set 3 | luba
# Processing Record 13 of Set 3 | puerto ayacucho
# Processing Record 14 of Set 3 | vila velha
# Processing Record 15 of Set 3 | stokmarknes
# Processing Record 16 of Set 3 | naustdal
# Processing Record 17 of Set 3 | meulaboh
# Processing Record 18 of Set 3 | hambantota
# Processing Record 19 of Set 3 | firovo
# Processing Record 20 of Set 3 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | bestobe
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | atar
# Processing Record 25 of Set 3 | muisne
# Processing Record 26 of Set 3 | mega
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 3 | shache
# Processing Record 30 of Set 3 | sabya
# Processing Record 31 of Set 3 | tubuala
# Processing Record 32 of Set 3 | hauterive
# Processing Record 33 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 34 of Set 3 | vila franca do campo
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | batangafo
# Processing Record 37 of Set 3 | grand-santi
# Processing Record 38 of Set 3 | winneba
# Processing Record 39 of Set 3 | oistins
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | nampula
# Processing Record 43 of Set 3 | kilrush
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | papenburg
# Processing Record 46 of Set 3 | radom
# Processing Record 47 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 3 | roald
# Processing Record 49 of Set 3 | huittinen
# Processing Record 50 of Set 3 | muchkapskiy
# Processing Record 1 of Set 4 | coueron
# Processing Record 2 of Set 4 | djambala
# Processing Record 3 of Set 4 | puerto quijarro
# Processing Record 4 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | pitimbu
# Processing Record 7 of Set 4 | dikson
# Processing Record 8 of Set 4 | havre-saint-pierre
# Processing Record 9 of Set 4 | tarko-sale
# Processing Record 10 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 11 of Set 4 | fraserburgh
# Processing Record 12 of Set 4 | lahti
# Processing Record 13 of Set 4 | muli
# Processing Record 14 of Set 4 | akhmim
# Processing Record 15 of Set 4 | ceres
# Processing Record 16 of Set 4 | pout
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | boa esperanca
# Processing Record 20 of Set 4 | isiro
# Processing Record 21 of Set 4 | tashtyp
# Processing Record 22 of Set 4 | tashtagol
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | suez
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | manpur
# Processing Record 28 of Set 4 | margate
# Processing Record 29 of Set 4 | faya
# Processing Record 30 of Set 4 | darab
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | iralaya
# Processing Record 33 of Set 4 | cidreira
# Processing Record 34 of Set 4 | sur
# Processing Record 35 of Set 4 | yanam
# Processing Record 36 of Set 4 | marsa matruh
# Processing Record 37 of Set 4 | santo amaro da imperatriz
# Processing Record 38 of Set 4 | antalaha
# Processing Record 39 of Set 4 | karpathos
# Processing Record 40 of Set 4 | challans
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | natal
# Processing Record 43 of Set 4 | wilmington island
# Processing Record 44 of Set 4 | shupiyan
# Processing Record 45 of Set 4 | praia da vitoria
# Processing Record 46 of Set 4 | formosa
# Processing Record 47 of Set 4 | songea
# Processing Record 48 of Set 4 | ati
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | veraval
# Processing Record 1 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 5 | chardara
# Processing Record 3 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 5 | nizwa
# Processing Record 5 of Set 5 | mehamn
# Processing Record 6 of Set 5 | coquimbo
# Processing Record 7 of Set 5 | takoradi
# Processing Record 8 of Set 5 | abiy adi
# City not found. Skipping...
# Processing Record 9 of Set 5 | raudeberg
# Processing Record 10 of Set 5 | apatity
# Processing Record 11 of Set 5 | harboore
# Processing Record 12 of Set 5 | zemio
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | grindavik
# Processing Record 15 of Set 5 | belmonte
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | necochea
# Processing Record 18 of Set 5 | bonavista
# Processing Record 19 of Set 5 | holme
# Processing Record 20 of Set 5 | douentza
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | kokkola
# Processing Record 23 of Set 5 | iglesias
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | alghero
# Processing Record 26 of Set 5 | oranjemund
# Processing Record 27 of Set 5 | sirna
# Processing Record 28 of Set 5 | martinez
# Processing Record 29 of Set 5 | bonfim
# Processing Record 30 of Set 5 | tereze
# Processing Record 31 of Set 5 | les cayes
# Processing Record 32 of Set 5 | asha
# Processing Record 33 of Set 5 | zychlin
# Processing Record 34 of Set 5 | ponta delgada
# Processing Record 35 of Set 5 | kyabe
# Processing Record 36 of Set 5 | ndjole
# Processing Record 37 of Set 5 | henties bay
# Processing Record 38 of Set 5 | nortelandia
# Processing Record 39 of Set 5 | leshukonskoye
# Processing Record 40 of Set 5 | bennington
# Processing Record 41 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 5 | the valley
# Processing Record 43 of Set 5 | oktyabrskoye
# Processing Record 44 of Set 5 | carnarvon
# Processing Record 45 of Set 5 | la plata
# Processing Record 46 of Set 5 | khash
# Processing Record 47 of Set 5 | puri
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | tromso
# Processing Record 1 of Set 6 | hire
# City not found. Skipping...
# Processing Record 2 of Set 6 | aneho
# Processing Record 3 of Set 6 | nisia floresta
# Processing Record 4 of Set 6 | sarakhs
# Processing Record 5 of Set 6 | lazurne
# Processing Record 6 of Set 6 | pangody
# Processing Record 7 of Set 6 | belize
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | naivasha
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | itaituba
# Processing Record 12 of Set 6 | kozluk
# Processing Record 13 of Set 6 | kaloz
# Processing Record 14 of Set 6 | bad frankenhausen
# Processing Record 15 of Set 6 | rocha
# Processing Record 16 of Set 6 | kamyshin
# Processing Record 17 of Set 6 | albion
# Processing Record 18 of Set 6 | shelburne
# Processing Record 19 of Set 6 | patacamaya
# Processing Record 20 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-francois
# Processing Record 22 of Set 6 | muros
# Processing Record 23 of Set 6 | atbasar
# Processing Record 24 of Set 6 | karaton
# Processing Record 25 of Set 6 | kalmunai
# Processing Record 26 of Set 6 | liwale
# Processing Record 27 of Set 6 | iranshahr
# Processing Record 28 of Set 6 | opuwo
# Processing Record 29 of Set 6 | marieville
# Processing Record 30 of Set 6 | nueve de julio
# Processing Record 31 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 6 | marawi
# Processing Record 33 of Set 6 | mecca
# Processing Record 34 of Set 6 | kutum
# Processing Record 35 of Set 6 | acari
# Processing Record 36 of Set 6 | bako
# Processing Record 37 of Set 6 | teguise
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | chotila
# Processing Record 40 of Set 6 | malakal
# Processing Record 41 of Set 6 | xambioa
# Processing Record 42 of Set 6 | leirvik
# Processing Record 43 of Set 6 | asfi
# Processing Record 44 of Set 6 | panaba
# Processing Record 45 of Set 6 | hobyo
# Processing Record 46 of Set 6 | belyy yar
# Processing Record 47 of Set 6 | ampanihy
# Processing Record 48 of Set 6 | baijiantan
# Processing Record 49 of Set 6 | kajaani
# Processing Record 50 of Set 6 | wesselsbron
# Processing Record 1 of Set 7 | gweta
# Processing Record 2 of Set 7 | porosozero
# Processing Record 3 of Set 7 | puerto baquerizo moreno
# Processing Record 4 of Set 7 | novyy urengoy
# Processing Record 5 of Set 7 | epe
# Processing Record 6 of Set 7 | kayes
# Processing Record 7 of Set 7 | buraydah
# Processing Record 8 of Set 7 | santander
# Processing Record 9 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 7 | visnes
# Processing Record 11 of Set 7 | bayir
# Processing Record 12 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 7 | qaqortoq
# Processing Record 14 of Set 7 | iracoubo
# Processing Record 15 of Set 7 | marovoay
# Processing Record 16 of Set 7 | quatre cocos
# Processing Record 17 of Set 7 | marystown
# Processing Record 18 of Set 7 | chapleau
# Processing Record 19 of Set 7 | altay
# Processing Record 20 of Set 7 | terrak
# Processing Record 21 of Set 7 | kamenka
# Processing Record 22 of Set 7 | sorland
# Processing Record 23 of Set 7 | bara
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | salvador
# Processing Record 26 of Set 7 | burica
# City not found. Skipping...
# Processing Record 27 of Set 7 | puerto maldonado
# Processing Record 28 of Set 7 | kindu
# Processing Record 29 of Set 7 | rio gallegos
# Processing Record 30 of Set 7 | rawson
# Processing Record 31 of Set 7 | ilo
# Processing Record 32 of Set 7 | novelda
# Processing Record 33 of Set 7 | nchelenge
# Processing Record 34 of Set 7 | makat
# Processing Record 35 of Set 7 | methala
# Processing Record 36 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 7 | ouadda
# Processing Record 38 of Set 7 | puerto narino
# Processing Record 39 of Set 7 | ust-tsilma
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | estreito
# Processing Record 42 of Set 7 | vestmannaeyjar
# Processing Record 43 of Set 7 | tortosa
# Processing Record 44 of Set 7 | najran
# Processing Record 45 of Set 7 | stephenville
# Processing Record 46 of Set 7 | palmas de monte alto
# Processing Record 47 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 48 of Set 7 | kisangani
# Processing Record 49 of Set 7 | mattru
# Processing Record 50 of Set 7 | lasa
# Processing Record 1 of Set 8 | cotonou
# Processing Record 2 of Set 8 | kachiry
# Processing Record 3 of Set 8 | kos
# Processing Record 4 of Set 8 | gat
# Processing Record 5 of Set 8 | pio ix
# Processing Record 6 of Set 8 | mahon
# Processing Record 7 of Set 8 | los algarrobos
# Processing Record 8 of Set 8 | kondinskoye
# Processing Record 9 of Set 8 | dakoro
# Processing Record 10 of Set 8 | pangnirtung
# Processing Record 11 of Set 8 | nalut
# Processing Record 12 of Set 8 | portlethen
# Processing Record 13 of Set 8 | yining
# Processing Record 14 of Set 8 | santa isabel do rio negro
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | eirunepe
# Processing Record 17 of Set 8 | salisbury
# Processing Record 18 of Set 8 | kalabo
# Processing Record 19 of Set 8 | bondo
# Processing Record 20 of Set 8 | villa carlos paz
# Processing Record 21 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 8 | gamba
# Processing Record 23 of Set 8 | santa maria
# Processing Record 24 of Set 8 | bar-le-duc
# Processing Record 25 of Set 8 | aljezur
# Processing Record 26 of Set 8 | niquero
# Processing Record 27 of Set 8 | marfino
# Processing Record 28 of Set 8 | matara
# Processing Record 29 of Set 8 | tamandare
# Processing Record 30 of Set 8 | saint-pierre
# Processing Record 31 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 8 | ferzikovo
# Processing Record 33 of Set 8 | senigallia
# Processing Record 34 of Set 8 | timra
# Processing Record 35 of Set 8 | finale emilia
# Processing Record 36 of Set 8 | cap-aux-meules
# Processing Record 37 of Set 8 | carutapera
# Processing Record 38 of Set 8 | wattegama
# Processing Record 39 of Set 8 | natitingou
# Processing Record 40 of Set 8 | angoche
# Processing Record 41 of Set 8 | leh
# Processing Record 42 of Set 8 | kortkeros
# Processing Record 43 of Set 8 | macia
# Processing Record 44 of Set 8 | ramsar
# Processing Record 45 of Set 8 | ripoll
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | filingue
# Processing Record 48 of Set 8 | tabuk
# Processing Record 49 of Set 8 | skibbereen
# Processing Record 50 of Set 8 | moose factory
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | aleksin
# Processing Record 3 of Set 9 | samur
# Processing Record 4 of Set 9 | areosa
# Processing Record 5 of Set 9 | nizhniy odes
# Processing Record 6 of Set 9 | zlitan
# Processing Record 7 of Set 9 | mayumba
# Processing Record 8 of Set 9 | sayyan
# Processing Record 9 of Set 9 | chambersburg
# Processing Record 10 of Set 9 | krasnogorskoye
# Processing Record 11 of Set 9 | bafra
# Processing Record 12 of Set 9 | chegem
# Processing Record 13 of Set 9 | huallanca
# Processing Record 14 of Set 9 | kouroussa
# Processing Record 15 of Set 9 | liverpool
# Processing Record 16 of Set 9 | palmeira
# Processing Record 17 of Set 9 | ukrayinka
# Processing Record 18 of Set 9 | padang
# Processing Record 19 of Set 9 | nottuln
# Processing Record 20 of Set 9 | eyl
# Processing Record 21 of Set 9 | maridi
# Processing Record 22 of Set 9 | araguacu
# Processing Record 23 of Set 9 | sao joao da barra
# Processing Record 24 of Set 9 | bull savanna
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | manyana
# Processing Record 27 of Set 9 | tsurib
# Processing Record 28 of Set 9 | shalya
# Processing Record 29 of Set 9 | magui
# City not found. Skipping...
# Processing Record 30 of Set 9 | fez
# Processing Record 31 of Set 9 | abu samrah
# Processing Record 32 of Set 9 | saint-augustin
# Processing Record 33 of Set 9 | muscle shoals
# Processing Record 34 of Set 9 | dehloran
# Processing Record 35 of Set 9 | rudbar
# Processing Record 36 of Set 9 | brunswick
# Processing Record 37 of Set 9 | yenagoa
# Processing Record 38 of Set 9 | pradera
# Processing Record 39 of Set 9 | moroni
# Processing Record 40 of Set 9 | cabedelo
# Processing Record 41 of Set 9 | vallenar
# Processing Record 42 of Set 9 | petropolis
# Processing Record 43 of Set 9 | taltal
# Processing Record 44 of Set 9 | thinadhoo
# Processing Record 45 of Set 9 | salekhard
# Processing Record 46 of Set 9 | severnoye
# Processing Record 47 of Set 9 | asyut
# Processing Record 48 of Set 9 | peruibe
# Processing Record 49 of Set 9 | sao miguel do araguaia
# Processing Record 50 of Set 9 | fontem
# Processing Record 1 of Set 10 | schoten
# Processing Record 2 of Set 10 | itarema
# Processing Record 3 of Set 10 | mekhelta
# City not found. Skipping...
# Processing Record 4 of Set 10 | antofagasta
# Processing Record 5 of Set 10 | banfora
# Processing Record 6 of Set 10 | kannapolis
# Processing Record 7 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 10 | touros
# Processing Record 9 of Set 10 | nizhnyaya tavda
# Processing Record 10 of Set 10 | flers
# Processing Record 11 of Set 10 | nizhniy baskunchak
# Processing Record 12 of Set 10 | anloga
# Processing Record 13 of Set 10 | oxford
# Processing Record 14 of Set 10 | selcuk
# Processing Record 15 of Set 10 | kudahuvadhoo
# Processing Record 16 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 10 | sainte-marie
# Processing Record 18 of Set 10 | kapoeta
# Processing Record 19 of Set 10 | novoseleznevo
# Processing Record 20 of Set 10 | rafaela
# Processing Record 21 of Set 10 | iquique
# Processing Record 22 of Set 10 | alakurtti
# Processing Record 23 of Set 10 | tukrah
# Processing Record 24 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 10 | inyonga
# Processing Record 26 of Set 10 | mikhaylovka
# Processing Record 27 of Set 10 | ogre
# Processing Record 28 of Set 10 | america dourada
# Processing Record 29 of Set 10 | sambava
# Processing Record 30 of Set 10 | arlit
# Processing Record 31 of Set 10 | la palma
# Processing Record 32 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 10 | lodwar
# Processing Record 34 of Set 10 | timbiqui
# Processing Record 35 of Set 10 | bandarbeyla
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | mahibadhoo
# Processing Record 39 of Set 10 | alta floresta
# Processing Record 40 of Set 10 | carmen
# Processing Record 41 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 10 | stara vyzhivka
# Processing Record 43 of Set 10 | ormara
# Processing Record 44 of Set 10 | gavle
# Processing Record 45 of Set 10 | fredericton
# Processing Record 46 of Set 10 | plettenberg bay
# Processing Record 47 of Set 10 | ciudad bolivar
# Processing Record 48 of Set 10 | requena
# Processing Record 49 of Set 10 | new ross
# Processing Record 50 of Set 10 | chicama
# Processing Record 1 of Set 11 | uribia
# Processing Record 2 of Set 11 | balsas
# Processing Record 3 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 4 of Set 11 | nuuk
# Processing Record 5 of Set 11 | la serena
# Processing Record 6 of Set 11 | dwarka
# Processing Record 7 of Set 11 | grootfontein
# Processing Record 8 of Set 11 | puerto ayora
# Processing Record 9 of Set 11 | igarka
# Processing Record 10 of Set 11 | palafrugell
# Processing Record 11 of Set 11 | krasnoborsk
# Processing Record 12 of Set 11 | namwala
# Processing Record 13 of Set 11 | sao jose da coroa grande
# Processing Record 14 of Set 11 | acarau
# Processing Record 15 of Set 11 | bage
# Processing Record 16 of Set 11 | pisco
# Processing Record 17 of Set 11 | segarcea
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | iquitos
# Processing Record 20 of Set 11 | gravdal
# Processing Record 21 of Set 11 | gallatin
# Processing Record 22 of Set 11 | constantine
# Processing Record 23 of Set 11 | samfya
# Processing Record 24 of Set 11 | riyadh
# Processing Record 25 of Set 11 | mao
# Processing Record 26 of Set 11 | abha
# Processing Record 27 of Set 11 | sorkjosen
# Processing Record 28 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 29 of Set 11 | canoas
# Processing Record 30 of Set 11 | awjilah
# Processing Record 31 of Set 11 | nalhati
# Processing Record 32 of Set 11 | jadu
# Processing Record 33 of Set 11 | comodoro rivadavia
# Processing Record 34 of Set 11 | kardailovo
# Processing Record 35 of Set 11 | san juan
# Processing Record 36 of Set 11 | lethem
# Processing Record 37 of Set 11 | iacu
# Processing Record 38 of Set 11 | san-pedro
# Processing Record 39 of Set 11 | dhidhdhoo
# Processing Record 40 of Set 11 | verkhnetulomskiy
# Processing Record 41 of Set 11 | kinanah
# City not found. Skipping...
# Processing Record 42 of Set 11 | kirgiz-miyaki
# Processing Record 43 of Set 11 | kalino
# Processing Record 44 of Set 11 | san juan de los morros
# Processing Record 45 of Set 11 | murwara
# Processing Record 46 of Set 11 | oxapampa
# Processing Record 47 of Set 11 | diffa
# Processing Record 48 of Set 11 | pandavapura
# Processing Record 49 of Set 11 | palamos
# Processing Record 50 of Set 11 | muscat
# Processing Record 1 of Set 12 | mindelo
# Processing Record 2 of Set 12 | aliquippa
# Processing Record 3 of Set 12 | mpulungu
# Processing Record 4 of Set 12 | kuytun
# Processing Record 5 of Set 12 | yarega
# Processing Record 6 of Set 12 | laurel
# Processing Record 7 of Set 12 | fort abbas
# Processing Record 8 of Set 12 | bubaque
# Processing Record 9 of Set 12 | mooi river
# City not found. Skipping...
# Processing Record 10 of Set 12 | kjustendil
# Processing Record 11 of Set 12 | los llanos de aridane
# Processing Record 12 of Set 12 | senanga
# Processing Record 13 of Set 12 | kazlu ruda
# Processing Record 14 of Set 12 | alekseyevka
# Processing Record 15 of Set 12 | umarkot
# Processing Record 16 of Set 12 | rafai
# Processing Record 17 of Set 12 | katete
# Processing Record 18 of Set 12 | sperkhias
# City not found. Skipping...
# Processing Record 19 of Set 12 | quiruvilca
# Processing Record 20 of Set 12 | salinas
# Processing Record 21 of Set 12 | sinnamary
# Processing Record 22 of Set 12 | tarrafal
# Processing Record 23 of Set 12 | nioki
# Processing Record 24 of Set 12 | stornoway
# Processing Record 25 of Set 12 | petauke
# Processing Record 26 of Set 12 | vuktyl
# Processing Record 27 of Set 12 | awbari
# Processing Record 28 of Set 12 | cartagena
# Processing Record 29 of Set 12 | kibala
# Processing Record 30 of Set 12 | lekoni
# Processing Record 31 of Set 12 | pottsville
# Processing Record 32 of Set 12 | senno
# Processing Record 33 of Set 12 | inta
# Processing Record 34 of Set 12 | krasnoselkup
# Processing Record 35 of Set 12 | taoudenni
# Processing Record 36 of Set 12 | blagoyevo
# Processing Record 37 of Set 12 | azul
# Processing Record 38 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 12 | shenkursk
# Processing Record 40 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 12 | parma
# Processing Record 42 of Set 12 | richards bay
# Processing Record 43 of Set 12 | sangmelima
# Processing Record 44 of Set 12 | naberera
# Processing Record 45 of Set 12 | mandera
# Processing Record 46 of Set 12 | narasannapeta
# Processing Record 47 of Set 12 | santa maria da vitoria
# Processing Record 48 of Set 12 | kelo
# Processing Record 49 of Set 12 | shahr-e babak
# Processing Record 50 of Set 12 | agirish
# Processing Record 1 of Set 13 | arkadak
# Processing Record 2 of Set 13 | podor
# Processing Record 3 of Set 13 | marathon
# Processing Record 4 of Set 13 | balykshi
# Processing Record 5 of Set 13 | hohoe
# Processing Record 6 of Set 13 | roches noires
# City not found. Skipping...
# Processing Record 7 of Set 13 | jimma
# Processing Record 8 of Set 13 | venice
# Processing Record 9 of Set 13 | urubicha
# Processing Record 10 of Set 13 | hoyanger
# Processing Record 11 of Set 13 | nesebar
# Processing Record 12 of Set 13 | umm kaddadah
# Processing Record 13 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 13 | albany
# Processing Record 15 of Set 13 | mana
# Processing Record 16 of Set 13 | sioni
# Processing Record 17 of Set 13 | piacabucu
# Processing Record 18 of Set 13 | arecibo
# Processing Record 19 of Set 13 | zeitz
# Processing Record 20 of Set 13 | lapua
# Processing Record 21 of Set 13 | malusteni
# Processing Record 22 of Set 13 | mogadishu
# Processing Record 23 of Set 13 | ayame
# Processing Record 24 of Set 13 | kabalo
# Processing Record 25 of Set 13 | arlington
# Processing Record 26 of Set 13 | apomu
# Processing Record 27 of Set 13 | mouzouras
# Processing Record 28 of Set 13 | wana
# Processing Record 29 of Set 13 | quixere
# Processing Record 30 of Set 13 | hastings
# Processing Record 31 of Set 13 | lucea
# Processing Record 32 of Set 13 | junagarh
# Processing Record 33 of Set 13 | dzilam gonzalez
# Processing Record 34 of Set 13 | jacqueville
# Processing Record 35 of Set 13 | norden
# Processing Record 36 of Set 13 | port blair
# Processing Record 37 of Set 13 | okoneshnikovo
# Processing Record 38 of Set 13 | hilton head island
# Processing Record 39 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 13 | soure
# Processing Record 41 of Set 13 | puerto colombia
# Processing Record 42 of Set 13 | padre bernardo
# Processing Record 43 of Set 13 | boulsa
# Processing Record 44 of Set 13 | maunabo
# Processing Record 45 of Set 13 | harbour breton
# Processing Record 46 of Set 13 | boa vista
# Processing Record 47 of Set 13 | pinega
# Processing Record 48 of Set 13 | pychas
# Processing Record 49 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 13 | zaysan
# Processing Record 1 of Set 14 | san rafael
# Processing Record 2 of Set 14 | amboasary
# Processing Record 3 of Set 14 | aketi
# Processing Record 4 of Set 14 | ampere
# Processing Record 5 of Set 14 | safranbolu
# Processing Record 6 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 7 of Set 14 | banda aceh
# Processing Record 8 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 9 of Set 14 | abaete
# Processing Record 10 of Set 14 | safaga
# Processing Record 11 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 14 | canutama
# Processing Record 13 of Set 14 | kongoussi
# Processing Record 14 of Set 14 | mosetse
# Processing Record 15 of Set 14 | edd
# Processing Record 16 of Set 14 | inhambane
# Processing Record 17 of Set 14 | goderich
# Processing Record 18 of Set 14 | lilongwe
# Processing Record 19 of Set 14 | padre paraiso
# Processing Record 20 of Set 14 | newport
# Processing Record 21 of Set 14 | chany
# Processing Record 22 of Set 14 | les escoumins
# Processing Record 23 of Set 14 | saint-joseph
# Processing Record 24 of Set 14 | copiapo
# Processing Record 25 of Set 14 | bay roberts
# Processing Record 26 of Set 14 | springdale
# Processing Record 27 of Set 14 | bedesa
# Processing Record 28 of Set 14 | zilair
# Processing Record 29 of Set 14 | salmas
# Processing Record 30 of Set 14 | trunovskoye
# Processing Record 31 of Set 14 | setermoen
# Processing Record 32 of Set 14 | huarmey
# Processing Record 33 of Set 14 | simoes
# Processing Record 34 of Set 14 | cockburn town
# Processing Record 35 of Set 14 | strangnas
# Processing Record 36 of Set 14 | nacala
# Processing Record 37 of Set 14 | urengoy
# Processing Record 38 of Set 14 | channel-port aux basques
# Processing Record 39 of Set 14 | otjimbingwe
# Processing Record 40 of Set 14 | partur
# Processing Record 41 of Set 14 | stromness
# Processing Record 42 of Set 14 | banikoara
# Processing Record 43 of Set 14 | tamluk
# Processing Record 44 of Set 14 | mantenopolis
# Processing Record 45 of Set 14 | male
# Processing Record 46 of Set 14 | kralendijk
# Processing Record 47 of Set 14 | pascagoula
# Processing Record 48 of Set 14 | izhma
# Processing Record 49 of Set 14 | rodrigues alves
# Processing Record 50 of Set 14 | la asuncion
# Processing Record 1 of Set 15 | paita
# Processing Record 2 of Set 15 | upington
# Processing Record 3 of Set 15 | baglung
# Processing Record 4 of Set 15 | cap malheureux
# Processing Record 5 of Set 15 | doka
# Processing Record 6 of Set 15 | hasanabad
# Processing Record 7 of Set 15 | barcelos
# Processing Record 8 of Set 15 | brae
# Processing Record 9 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 15 | marzuq
# Processing Record 11 of Set 15 | iberia
# Processing Record 12 of Set 15 | hommelvik
# Processing Record 13 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 15 | meridian
# Processing Record 15 of Set 15 | ipanema
# Processing Record 16 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 17 of Set 15 | ergani
# Processing Record 18 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | umea
# Processing Record 20 of Set 15 | saposoa
# Processing Record 21 of Set 15 | umm lajj
# Processing Record 22 of Set 15 | lulea
# Processing Record 23 of Set 15 | batsfjord
# Processing Record 24 of Set 15 | juazeirinho
# Processing Record 25 of Set 15 | brest
# Processing Record 26 of Set 15 | ntchisi
# Processing Record 27 of Set 15 | waling
# Processing Record 28 of Set 15 | koygorodok
# Processing Record 29 of Set 15 | abay
# Processing Record 30 of Set 15 | limbe
# Processing Record 31 of Set 15 | altukhovo
# Processing Record 32 of Set 15 | torres
# Processing Record 33 of Set 15 | dharmavaram
# Processing Record 34 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 15 | pelym
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
# Convert the array of dictionaries to a Pandas Dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#                   City Country                 Date      Lat      Lng  \
# 0            Mahebourg      MU  2022-07-07 16:10:49 -20.4081  57.7000
# 1  Verkhniy Baskunchak      RU  2022-07-07 16:10:49  48.2256  46.7217
# 2             Westport      US  2022-07-07 16:10:41  41.1415 -73.3579
# 3                  Kem      RU  2022-07-07 16:10:49  64.9555  34.5793
# 4               Namibe      AO  2022-07-07 16:10:50 -15.1961  12.1522
# 5             Kargasok      RU  2022-07-07 16:10:50  59.0556  80.8572
# 6               Manaus      BR  2022-07-07 16:09:07  -3.1019 -60.0250
# 7         Longyearbyen      SJ  2022-07-07 16:10:50  78.2186  15.6401
# 8         Jacareacanga      BR  2022-07-07 16:10:50  -6.2222 -57.7528
# 9            Jamestown      US  2022-07-07 16:10:51  42.0970 -79.2353
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     70.09        68          75       16.11       broken clouds
# 1     85.17        23           0        6.53           clear sky
# 2     82.72        59          56        4.00       broken clouds
# 3     59.94        72         100        7.31     overcast clouds
# 4     67.87        80           4        8.75           clear sky
# 5     62.87        70          78        5.53       broken clouds
# 6     90.09        62          40        8.05    scattered clouds
# 7     48.04        53          20       16.11          few clouds
# 8     93.81        36           3        4.52           clear sky
# 9     80.02        64          75        8.05       broken clouds

# %%
# Create an output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
